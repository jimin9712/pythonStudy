# %% [markdown]
# # **1. 경로**
# - 절대 경로 : 디스크 드라이브의 최상위(root) 디렉토리부터 텍스트 파일이 저장될 디렉토리까지 경로
#   - 예) C:\hogeun\Day01\venv\Scripts
# - 상대 경로 : 현재 화면에 표시되는 소스파일이 위치한 디렉토리부터 텍스트 파일이 저장될 디렉토리까지의 경로
#   - 같은 디렉토리 : 파일명
#   - 상위 디렉토리 : ../파일명
#   - 하위디렉토리 : 디렉토리명/파일명

# %% [markdown]
# # **2.  파일 열기**
# ```
# 파일변수 = open('파일 경로', '파일 열기 모드')
# ```
# - 파일 열기 모드 : w(출력), a(추가출력), r(입력)
# - w는 지정된 경로에 파일이 없으면 파일을 만든 후 저장하고, 파일이 있으면 기존의 모든 데이터를 지우고 다시 저장
# - a는 지정된 경로에 파일이 없으면 파일을 만든 후 저장하고, 파일이 있으면 기존의 데이터 뒤에 이어서 저장
# - r은 지정된 경로에 파일이 없으면 에러, 있으면 해당 파일의 데이터를 읽어옴
# ```
# file = open('./test.txt', 'rt') # 텍스트파일 열기 모드
# file = open('./test.txt', 'rb') # 바이너리파일 열기 모드
# ```
# - 파일의 종류 구분 : t(text, 생략가능), b(binary) 바이너리는 영상이나 음악, 등등
# ✔ 출력 시(w, a) 작업이 완료되면 반드시 close() 메소드를 사용해서 파일을 닫아야 정상적으로 데이터가 저장됨

# %% [markdown]
# # **3. 파일에 출력**

# %%
file = open('./data.txt', 'wt')
for i in range(10):
  file.write('파일에 write 테스트' + str(i) + '\n')
  file.close

# %% [markdown]
# # **4. 파일 읽기**

# %%
# read() : 파일로부터 데이터를 읽어옴
# file.read(size) 또는 file.read()

file = open('data.txt','rt')
data = file.read(20)
data1 = file.read()
print(data1)
# Out:
# rite 테스트1
# 파일에 write 테스트2
# 파일에 write 테스트3
# 파일에 write 테스트4
# 파일에 write 테스트5
# 파일에 write 테스트6
# 파일에 write 테스트7
# 파일에 write 테스트8
# 파일에 write 테스트9
